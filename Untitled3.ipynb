# %%
query = "SELECT TICKETID AS \"Ticketid\","+\
"WEEK AS \"Calendar Week\"," + \
"TO_CHAR(TICKET_CREATE_TIME, 'fmMM/DDfm/YYYY fmHHfm:MI:SS AM') AS \"Ticket Create Time\"," + \
"CURRENT_PRIORITY AS \"Priority\", "+ \
"STATUS AS \"Status\", "+ \
"REGION AS \"Region\", "+"SITE AS \"Site\"," + \
"NOTES AS \"Problem Description\","+ \
"GENERAL_CATEGORY AS \"General Category\","+ \
"SUB_CATEGORY AS \"Sub Category\","+ \
"RESOLUTION AS \"Resolution\","+ \
"CUSTOMER_DEPARTMENT AS \"Customer Department\" "+ \
"FROM(SELECT A.TICKETID,"+ \
"E.WEEK,"+ \
"CAST(FROM_TZ (CAST(A.TICKET_CREATE_TIME AS TIMESTAMP), 'Europe/Berlin') AT TIME ZONE 'Asia/Kuala_Lumpur' AS TIMESTAMP) AS TICKET_CREATE_TIME," + \
"A.CURRENT_PRIORITY,"+ \
"C.STATUS," + \
"A.REGION," + \
"A.SITE," + \
"A.NOTES,"+ \
"A.SUPPORT_GROUP_ID AS SUPPORT_GROUP_ID,"+ \
"D.VARIABLE_NAME AS GENERAL_CATEGORY,"+ \
"D.VARIABLE_DISPLAY AS SUB_CATEGORY,"+ \
"B.RESOLUTION,"+ \
"A.CUSTOMER_DEPARTMENT "+ \
"FROM GLB_AL_REMEDY.ITSM7_TICKETINFORMATION A "+ \
"JOIN GLB_AL_REMEDY.ITSM7_INCIDENT_INFO B "+ \
"ON(A.TICKETID = B.TICKETID) "+ \
"JOIN GLB_AL_REMEDY.ITSM7_TICKETSTATUS_INFO C "+ \
"ON(A.TICKETID = C.TICKETID) "+ \
"JOIN GLB_AL_REMEDY.XML_GTW_TICKETACTION D "+ \
"ON(A.TICKETID = D.TICKETID) "+ \
"JOIN GLB_AL_REMEDY.PR_DIM_ITSM7_CALTIME E "+ \
"ON(A.DAY_ID_LAST_RESOLVED = E.DAY_ID) "+ \
"WHERE A.TICKET_CREATE_TIME >= TO_DATE('25/09/2020', 'DD/MM/YYYY') "+ \
"AND A.SUPPORT_GROUP_ID = '144823' "+ \
"AND A.PRODUCT_NAME = 'Camstar BE' "+ \
"AND C.STATUS = 'Closed' "+ \
"AND INSTR(D.CATEGORY, 'Camstar BE - Incident') > 0 "+ \
"AND D.VARIABLE_DISPLAY IS NOT NULL) "+ \
"ORDER BY TICKETID DESC"

# %%
# import pandas as pd
# from sqlalchemy import create_engine
# class OracleData:
#     def __init__(self, connection_String, username, password, hostname, port, database):
#         self.oracle_connection_string = connection_String
#         self.engine = create_engine(
#         oracle_connection_string.format(
#         username=username,
#         password = password,
#         hostname = hostname,
#         port = port,
#         database = database,
#         ))
#     def Query(self, query):
#         return pd.read_sql(query, self.engine)
#     def save_data(self, df, name):
#         return df.to_excel(name)

# %%
query ="SELECT * FROM a_printdata"

# %%
import import_ipynb
from APIs.OracleData import OracleData

connection_String = "oracle+cx_oracle://itsm7_read:read@edwh-db.vih.infineon.com:1522/edwh"
''' Please use this format: oracle_cx_oracle://{username}:{password}@{hostname}:{port}/{SID or the database name}'''
username = "itsm7_read"
password = "read"
hostname = "edwh-db.vih.infineon.com"
port = "1522"
database = "edwh"

connection = OracleData(connection_String, username, password, hostname, port, database)
df = connection.Query(query)
connection.save_data(df,"database.xlsx")
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# /home/fibebocai/virtualenvs/fibebocai_text/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1802                     self.dialect.do_execute(
# -> 1803                         cursor, statement, parameters, context
#    1804                     )
#
# /home/fibebocai/virtualenvs/fibebocai_text/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     731     def do_execute(self, cursor, statement, parameters, context=None):
# --> 732         cursor.execute(statement, parameters)
#     733
#
# DatabaseError: ORA-00942: table or view does not exist
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# /tmp/ipykernel_18446/1078809284.py in <module>
#      11
#      12 connection = OracleData(connection_String, username, password, hostname, port, database)
# ---> 13 df = connection.Query(query)
#      14 connection.save_data(df,"database.xlsx")
#
# /home/fibebocai/ReactiveProactive/Manna/APIs/OracleData.py in Query(self, query)
#      12         ))
#      13     def Query(self, query):
# ---> 14         return pd.read_sql(query, self.engine)
#      15     def save_data(self, df, name):
#      16         return df.to_excel(name)
#
# /home/fibebocai/virtualenvs/fibebocai_text/lib/python3.7/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     632             coerce_float=coerce_float,
#     633             parse_dates=parse_dates,
# --> 634             chunksize=chunksize,
#     635         )
#     636
#
# /home/fibebocai/virtualenvs/fibebocai_text/lib/python3.7/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1577         args = _convert_params(sql, params)
#    1578
# -> 1579         result = self.execute(*args)
#    1580         columns = result.keys()
#    1581
#
# /home/fibebocai/virtualenvs/fibebocai_text/lib/python3.7/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1422     def execute(self, *args, **kwargs):
#    1423         """Simple passthrough to SQLAlchemy connectable"""
# -> 1424         return self.connectable.execution_options().execute(*args, **kwargs)
#    1425
#    1426     def read_table(
#
# <string> in execute(self, statement, *multiparams, **params)
#
# /home/fibebocai/virtualenvs/fibebocai_text/lib/python3.7/site-packages/sqlalchemy/util/deprecations.py in warned(fn, *args, **kwargs)
#     399         if not skip_warning:
#     400             _warn_with_version(message, version, wtype, stacklevel=3)
# --> 401         return fn(*args, **kwargs)
#     402
#     403     doc = func.__doc__ is not None and func.__doc__ or ""
#
# /home/fibebocai/virtualenvs/fibebocai_text/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    3144         """
#    3145         connection = self.connect(close_with_result=True)
# -> 3146         return connection.execute(statement, *multiparams, **params)
#    3147
#    3148     @util.deprecated_20(
#
# /home/fibebocai/virtualenvs/fibebocai_text/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    1277                 params,
#    1278                 _EMPTY_EXECUTION_OPTS,
# -> 1279                 future=False,
#    1280             )
#    1281
#
# /home/fibebocai/virtualenvs/fibebocai_text/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1583             execution_options,
#    1584             statement,
# -> 1585             distilled_parameters,
#    1586         )
#    1587
#
# /home/fibebocai/virtualenvs/fibebocai_text/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844         except BaseException as e:
#    1845             self._handle_dbapi_exception(
# -> 1846                 e, statement, parameters, cursor, context
#    1847             )
#    1848
#
# /home/fibebocai/virtualenvs/fibebocai_text/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2025             elif should_wrap:
#    2026                 util.raise_(
# -> 2027                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2028                 )
#    2029             else:
#
# /home/fibebocai/virtualenvs/fibebocai_text/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# /home/fibebocai/virtualenvs/fibebocai_text/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1801                 if not evt_handled:
#    1802                     self.dialect.do_execute(
# -> 1803                         cursor, statement, parameters, context
#    1804                     )
#    1805
#
# /home/fibebocai/virtualenvs/fibebocai_text/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     730
#     731     def do_execute(self, cursor, statement, parameters, context=None):
# --> 732         cursor.execute(statement, parameters)
#     733
#     734     def do_execute_no_params(self, cursor, statement, context=None):
#
# DatabaseError: (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist
# [SQL: SELECT * FROM a_printdata ]
# (Background on this error at: https://sqlalche.me/e/14/4xp6)

# %%
df
# Out:
#              Ticketid Calendar Week      Ticket Create Time  Priority  Status  \
# 0     INC000006037028   CW: 2022/22    6/1/2022 11:37:16 AM       Low  Closed
# 1     INC000006036937   CW: 2022/22    6/1/2022 12:30:08 PM  Critical  Closed
# 2     INC000006036916   CW: 2022/22    6/1/2022 10:54:26 AM       Low  Closed
# 3     INC000006036601   CW: 2022/22    6/1/2022 10:39:12 AM  Critical  Closed
# 4     INC000006036584   CW: 2022/22    6/1/2022 10:21:25 AM      High  Closed
# ...               ...           ...                     ...       ...     ...
# 8045  INC000005011660   CW: 2020/53   12/29/2020 1:39:14 AM  Critical  Closed
# 8046  INC000005011643   CW: 2020/53  12/28/2020 11:59:33 PM  Critical  Closed
# 8047  INC000005011631   CW: 2020/53  12/28/2020 10:53:58 PM  Critical  Closed
# 8048  INC000005011607   CW: 2020/53   12/29/2020 3:39:20 AM       Low  Closed
# 8049  INC000005011280   CW: 2021/01   12/28/2020 5:46:56 PM       Low  Closed
#
#      Region       Site                                Problem Description  \
# 0        AP      Batam  (1) Problem description on error* (Including s...
# 1        AP     Melaka  (1) Problem description on error* (Including s...
# 2        AP      Batam  (1) Problem description on error* (Including s...
# 3        AP     Melaka  (1) Problem description on error* (Including s...
# 4        AP     Melaka  (1) Problem description on error* (Including s...
# ...     ...        ...                                                ...
# 8045     AP  Singapore  (1) Problem description on error*: (Including ...
# 8046     AP       Wuxi  (1) Problem description on error*: (Including ...
# 8047     AP     Melaka  (1) Problem description on error*: (Including ...
# 8048     AP     Melaka  (1) Problem description on error*: (Including ...
# 8049     AP     Melaka  , INFINEON\Ruslan, MKZ, \n\n1F052809G03\nSIR03...
#
#                       General Category                      Sub Category  \
# 0       Incident Category: Integration                  JCBE-Invalid Job
# 1        Incident Category: Procedural  Material Setup/GK Material Setup
# 2       Incident Category: Integration                  JCBE-Invalid Job
# 3          Incident Category: Platform                Database-Archiving
# 4       Incident Category: Integration                               EAF
# ...                                ...                               ...
# 8045    Incident Category: Integration                  FAJM-Invalid Job
# 8046  Incident Category: Configuration                            Others
# 8047     Incident Category: Procedural                            Others
# 8048     Incident Category: Procedural                            Others
# 8049    Incident Category: Integration                            Others
#
#                                              Resolution  \
# 0     1) Findings:\nthe issue is invalid FAjob from ...
# 1     1) Findings:\nBar Code number:\n[)><RS>06<GS>P...
# 2     1) Findings:\nthe issue is invalid FAjob from ...
# 3     1) Findings:\nWhen lot start, the lot was term...
# 4     1) Findings:\nMPL003 is not communicating.\nMP...
# ...                                                 ...
# 8045  Invalid job was aborted, user may proceed as u...
# 8046  User need to contact UPE for this incident sin...
# 8047  Aborted the invalid FAJOB:ZA032102G02SUBCON_PL...
# 8048  Procedural Error:\nZA026012M0I at the beginnin...
# 8049  User require to provide Test Summary so we can...
#
#             Customer Department
# 0       BE POB SO T M PROD TEST
# 1            BE P M1 SON MFG1 A
# 2      BE POB SO T M PROD MSP C
# 3       BE P M2 SCCM E A PRS ES
# 4          BE P M3 BI MFG DPL A
# ...                         ...
# 8045            BE TS SO P FT C
# 8046           BE P OP MP3 LC D
# 8047  BE PLA SO QFP P EOL A TL2
# 8048    BE SCC SO M2 P 1 A ASSY
# 8049    BE PLT SO M2 P STD B1 1
#
# [8050 rows x 12 columns]
